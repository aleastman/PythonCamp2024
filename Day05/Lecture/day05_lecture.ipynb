# %% [markdown]
# #### Day 5: APIs
#
# API stands for:
# - Application (a piece of software, a computer program, or a server)
# - Programming (what you’re doing with python)
# - Interface (how you’re communicating)
#
#
# How It Works:
# - Every Internet page is stored on a remote server
# - When you go to a website, a request goes out to their remote server
# - Your browser (the client) receives the response
# - When surfing the web, the API is the part of the remote server that receives requests and sends responses
# - Informative explanation: https://towardsdatascience.com/what-is-an-api-and-how-does-it-work-1dccd7a8219e
#
# How Developers Use It:
# - The app’s functionality requires photography (think SnapChat)
# - iPhone devs already made camera software & efficient translations of inputs to outputs
# - Devs can use that software instead of writing it from scratch! (gains from trade)
# - Use the iPhone camera API to embed photography functions in your app
# - When Apple upgrades the camera software, your app benefits from the improvements
# - Another non-technical explanation: https://www.howtogeek.com/343877/what-is-an-api/
#
# **How We (social scientists) Use It:**
# - Tools:
# 	1. Google Cloud Speech API
# 	2. Microsoft Azure Emotion API
#
# - Data:
# 	1. Census
# 	2. GoogleMaps
# 	3. Twitter/Meta/Reddit/etc.
# 	4. FEC
# 	5. Legislative data (e.g., UK and Brazil Parliaments)
#
# All APIs are different, and each has its own learning curve.
# - Some require account keys to keep these private
# - Most have request limits
# - Some are not free
#
# For this course, we are only using python wrappers for APIs, but R also offers API wrappers.
#
# If you prefer to use R, look for these prior to writing your code.
#
# ***

# %% [markdown]
# ##### Part 1: Spotify API
#
# `Spotipy` is a lightweight python library for the Spotify Web API.
#
# With `Spotipy`, you get full access to all of the music data provided by the Spotify platform.
#
# Here is the documentation: https://spotipy.readthedocs.io/en/2.22.1/

# %% [markdown]
# 1. Installation

# %%
# !pip3 install spotipy --upgrade
# Out:
# Collecting spotipy
#   Downloading spotipy-2.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.8-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (2024.7.4)
# Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)
# Downloading redis-5.0.8-py3-none-any.whl (255 kB)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.8 spotipy-2.24.0

# %% [markdown]
# 2. Get your credentials
#     - Go to: https://developer.spotify.com/dashboard
#     - Log in (or create a Spotify account if you don't already have one)
#     - Create an app (You don't need the Redirect URL, but just put down some random website)
#     - Request an access token: get your client ID and client secret

# %%
# It is best practice to store these in a separate file, but for demonstration we will just use this
client_id = 'YOUR_CLIENT_ID'
client_secret = 'YOUR_CLIENT_SECRET'

# %% [markdown]
# 3. Import libraries

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# 4. Use your credentials

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id,
                                                                              client_secret=client_secret))

# %% [markdown]
# ##### An example usecase: Let's search for Taylor Swift and find all her albums
#
# 1. Find her identifier

# %%
# from artist's uri on spotify: https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02
taylor_uri = '06HL4z0CvFAxyc27GXpf02'

# %% [markdown]
# 2. Use the method `.artist_albums()` to find her albums

# %%
results = spotify.artist_albums(taylor_uri, album_type='album')

# %% [markdown]
# Let's check the output we got from `results`

# %%
print(results)
#dictionary
#very nested output, so spend some time figuring out the structure
# Out:
# {'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02/albums?include_groups=album&offset=0&limit=20', 'items': [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}, 'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02', 'id': '06HL4z0CvFAxyc27GXpf02', 'name': 'Taylor Swift', 'type': 'artist', 'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5H7ixXZfsNMGbIE5OBSpcb'}, 'href': 'https://api.spotify.com/v1/albums/5H7ixXZfsNMGbIE5OBSpcb', 'id': '5H7ixXZfsNMGbIE5OBSpcb', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2738ecc33f195df6aa257c39eaa', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e028ecc33f195df6aa257c39eaa', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048518ecc33f195df6aa257c39eaa', 'width': 64}], 'name': 'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY', 'release_date': '2024-04-19', 'release_date_precision': 'day', 'total_tracks': 31, 'type': 'album', 'uri': 'spotify:album:5H7ixXZfsNMGbIE5OBSpcb'}, {'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}, 'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02', 'id': '06HL4z0CvFAxyc27GXpf02', 'name': 'Taylor Swift', 'type': 'artist', 'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'}, 'href': 'https://api.spotify.com/v1/albums/1Mo4aZ8pdj6L1jx8zSwJnt', 'id': '1Mo4aZ8pdj6L1jx8zSwJnt', 'images': [{'height': 640, 'url': 'https:/ ...

# %% [markdown]
# What is the data type?

# %%
type(results)
# Out:
# dict

# %% [markdown]
# What are the keys of this dictionary?

# %%
#starting with the top level 
results.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# Which of these stores the name of the album?

# %%
albums = results['items']
albums
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5H7ixXZfsNMGbIE5OBSpcb'},
#   'href': 'https://api.spotify.com/v1/albums/5H7ixXZfsNMGbIE5OBSpcb',
#   'id': '5H7ixXZfsNMGbIE5OBSpcb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738ecc33f195df6aa257c39eaa',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028ecc33f195df6aa257c39eaa',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518ecc33f195df6aa257c39eaa',
#     'width': 64}],
#   'name': 'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY',
#   'release_date': '2024-04-19',
#   'release_date_precision': 'day',
#   'total_tracks': 31,
#   'type': 'album',
#   'uri': 'spotify:album:5H7ixXZfsNMGbIE5OBSpcb'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'},
#   'href': 'https://api.spotify.com/v1/albums/1Mo4aZ8pdj6L1jx8zSwJnt',
#   'id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735076e4160d018e378f488c33',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025076e4160d018e378f488c33',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515076e4160d018e378f488c33',
#     'width': 64}],
#   'name': 'THE TORTURED POETS DEPARTMENT',
#   'release_date': '2024-04-18',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:1Mo4aZ8pdj6L1jx8zSwJnt'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1o59UpKw81iHR0HPiSkJR0'},
#   'href': 'https://api.spotify.com/v1/albums/1o59UpKw81iHR0HPiSkJR0',
#   'id': '1o59UpKw81iHR0HPiSkJR0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273dc2bacae1dca83d26e2b1949',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02dc2bacae1dca83d26e2b1949',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851dc2bacae1dca83d26e2b1949',
#     'width': 64}],
#   'name': "1989 (Taylor's Version) [Deluxe]",
#   'release_date': '2023-10-27',
#   'release_date_precision': 'day',
#   'total_tracks': 22,
#   'type': 'album',
#   'uri': 'spotify:album:1o59UpKw81iHR0HPiSkJR0'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'},
#   'href': 'https://api.spotify.com/v1/albums/64LU4c1nfjz1t4VnGhagcg',
#   'id': '64LU4c1nfjz1t4VnGhagcg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273904445d70d04eb24d6bb79ac',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02904445d70d04eb24d6bb79ac',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851904445d70d04eb24d6bb79ac',
#     'width': 64}],
#   'name': "1989 (Taylor's Version)",
#   'release_date': '2023-10-26',
#   'release_date_precision': 'day',
#   'total_tracks': 21,
#   'type': 'album',
#   'uri': 'spotify:album:64LU4c1nfjz1t4VnGhagcg'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5AEDGbliTTfjOB8TSm1sxt'},
#   'href': 'https://api.spotify.com/v1/albums/5AEDGbliTTfjOB8TSm1sxt',
#   'id': '5AEDGbliTTfjOB8TSm1sxt',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730b04da4f224b51ff86e0a481',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020b04da4f224b51ff86e0a481',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510b04da4f224b51ff86e0a481',
#     'width': 64}],
#   'name': "Speak Now (Taylor's Version)",
#   'release_date': '2023-07-07',
#   'release_date_precision': 'day',
#   'total_tracks': 22,
#   'type': 'album',
#   'uri': 'spotify:album:5AEDGbliTTfjOB8TSm1sxt'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1fnJ7k0bllNfL1kVdNVW1A'},
#   'href': 'https://api.spotify.com/v1/albums/1fnJ7k0bllNfL1kVdNVW1A',
#   'id': '1fnJ7k0bllNfL1kVdNVW1A',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fa747621a53c8e2cc436dee0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fa747621a53c8e2cc436dee0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fa747621a53c8e2cc436dee0',
#     'width': 64}],
#   'name': 'Midnights (The Til Dawn Edition)',
#   'release_date': '2023-05-26',
#   'release_date_precision': 'day',
#   'total_tracks': 23,
#   'type': 'album',
#   'uri': 'spotify:album:1fnJ7k0bllNfL1kVdNVW1A'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3lS1y25WAhcqJDATJK70Mq'},
#   'href': 'https://api.spotify.com/v1/albums/3lS1y25WAhcqJDATJK70Mq',
#   'id': '3lS1y25WAhcqJDATJK70Mq',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e0b60c608586d88252b8fbc0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e0b60c608586d88252b8fbc0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e0b60c608586d88252b8fbc0',
#     'width': 64}],
#   'name': 'Midnights (3am Edition)',
#   'release_date': '2022-10-22',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:3lS1y25WAhcqJDATJK70Mq'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/151w1FgRZfnKZA9FEcg9Z3'},
#   'href': 'https://api.spotify.com/v1/albums/151w1FgRZfnKZA9FEcg9Z3',
#   'id': '151w1FgRZfnKZA9FEcg9Z3',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bb54dde68cd23e2a268ae0f5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bb54dde68cd23e2a268ae0f5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bb54dde68cd23e2a268ae0f5',
#     'width': 64}],
#   'name': 'Midnights',
#   'release_date': '2022-10-21',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:151w1FgRZfnKZA9FEcg9Z3'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6kZ42qRrzov54LcAk4onW9'},
#   'href': 'https://api.spotify.com/v1/albums/6kZ42qRrzov54LcAk4onW9',
#   'id': '6kZ42qRrzov54LcAk4onW9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02318443aab3531a0558e79a4d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851318443aab3531a0558e79a4d',
#     'width': 64}],
#   'name': "Red (Taylor's Version)",
#   'release_date': '2021-11-12',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:6kZ42qRrzov54LcAk4onW9'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#   'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#   'id': '4hDok0OAJd57SGIT8xuWJH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#     'width': 64}],
#   'name': "Fearless (Taylor's Version)",
#   'release_date': '2021-04-09',
#   'release_date_precision': 'day',
#   'total_tracks': 26,
#   'type': 'album',
#   'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG'},
#   'href': 'https://api.spotify.com/v1/albums/6AORtDjduMM3bupSWzbTSG',
#   'id': '6AORtDjduMM3bupSWzbTSG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0290fd9741e1838115cd90b3b6',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485190fd9741e1838115cd90b3b6',
#     'width': 64}],
#   'name': 'evermore (deluxe version)',
#   'release_date': '2021-01-07',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:6AORtDjduMM3bupSWzbTSG'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2Xoteh7uEpea4TohMxjtaq'},
#   'href': 'https://api.spotify.com/v1/albums/2Xoteh7uEpea4TohMxjtaq',
#   'id': '2Xoteh7uEpea4TohMxjtaq',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27333b8541201f1ef38941024be',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0233b8541201f1ef38941024be',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485133b8541201f1ef38941024be',
#     'width': 64}],
#   'name': 'evermore',
#   'release_date': '2020-12-11',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:2Xoteh7uEpea4TohMxjtaq'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0PZ7lAru5FDFHuirTkWe9Z'},
#   'href': 'https://api.spotify.com/v1/albums/0PZ7lAru5FDFHuirTkWe9Z',
#   'id': '0PZ7lAru5FDFHuirTkWe9Z',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273045514e3ed4e1767a7c3ece5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02045514e3ed4e1767a7c3ece5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851045514e3ed4e1767a7c3ece5',
#     'width': 64}],
#   'name': 'folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]',
#   'release_date': '2020-11-25',
#   'release_date_precision': 'day',
#   'total_tracks': 34,
#   'type': 'album',
#   'uri': 'spotify:album:0PZ7lAru5FDFHuirTkWe9Z'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1pzvBxYgT6OVwJLtHkrdQK'},
#   'href': 'https://api.spotify.com/v1/albums/1pzvBxYgT6OVwJLtHkrdQK',
#   'id': '1pzvBxYgT6OVwJLtHkrdQK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c288028c2592f400dd0b9233',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c288028c2592f400dd0b9233',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c288028c2592f400dd0b9233',
#     'width': 64}],
#   'name': 'folklore (deluxe version)',
#   'release_date': '2020-08-18',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:1pzvBxYgT6OVwJLtHkrdQK'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#   'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#   'id': '2fenSS68JI1h4Fo296JfGr',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#     'width': 64}],
#   'name': 'folklore',
#   'release_date': '2020-07-24',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#   'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#   'id': '1NAmidJlEaVgA3MpcPFYGq',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#     'width': 64}],
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#   'href': 'https://api.spotify.com/v1/albums/6DEjYFkNZh67HP7R9PSZvv',
#   'id': '6DEjYFkNZh67HP7R9PSZvv',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273da5d5aeeabacacc1263c0f4b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851da5d5aeeabacacc1263c0f4b',
#     'width': 64}],
#   'name': 'reputation',
#   'release_date': '2017-11-10',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:6DEjYFkNZh67HP7R9PSZvv'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1MPAXuTVL2Ej5x0JHiSPq8'},
#   'href': 'https://api.spotify.com/v1/albums/1MPAXuTVL2Ej5x0JHiSPq8',
#   'id': '1MPAXuTVL2Ej5x0JHiSPq8',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27363d77f99117b28af9f656918',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0263d77f99117b28af9f656918',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485163d77f99117b28af9f656918',
#     'width': 64}],
#   'name': 'reputation Stadium Tour Surprise Song Playlist',
#   'release_date': '2017-11-09',
#   'release_date_precision': 'day',
#   'total_tracks': 46,
#   'type': 'album',
#   'uri': 'spotify:album:1MPAXuTVL2Ej5x0JHiSPq8'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['CA', 'US'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/34OkZVpuzBa9y40DCy0LPR'},
#   'href': 'https://api.spotify.com/v1/albums/34OkZVpuzBa9y40DCy0LPR',
#   'id': '34OkZVpuzBa9y40DCy0LPR',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273332d85510aba3eb28312cfb2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02332d85510aba3eb28312cfb2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851332d85510aba3eb28312cfb2',
#     'width': 64}],
#   'name': '1989 (Deluxe Edition)',
#   'release_date': '2014-10-27',
#   'release_date_precision': 'day',
#   'total_tracks': 19,
#   'type': 'album',
#   'uri': 'spotify:album:34OkZVpuzBa9y40DCy0LPR'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['CA', 'US'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#   'href': 'https://api.spotify.com/v1/albums/2QJmrSgbdM35R67eoGQo4j',
#   'id': '2QJmrSgbdM35R67eoGQo4j',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739abdf14e6058bd3903686148',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029abdf14e6058bd3903686148',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519abdf14e6058bd3903686148',
#     'width': 64}],
#   'name': '1989',
#   'release_date': '2014-10-27',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:2QJmrSgbdM35R67eoGQo4j'}]

# %% [markdown]
# What is the data type?

# %%
type(albums)
len(albums)
# Out:
# list

# %% [markdown]
# Let's look at the first element

# %%
albums[0]# ['name']
albums[0]['name']
# Out:
# 'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY'

# %% [markdown]
# Now, let's make sure it gets all of the albums by iterating through all pages.

# %%
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

# %% [markdown]
# Let's check the results!

# %%
for album in albums:
    print(album['name'])
# Out:
# THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# THE TORTURED POETS DEPARTMENT
# 1989 (Taylor's Version) [Deluxe]
# 1989 (Taylor's Version)
# Speak Now (Taylor's Version)
# Midnights (The Til Dawn Edition)
# Midnights (3am Edition)
# Midnights
# Red (Taylor's Version)
# Fearless (Taylor's Version)
# evermore (deluxe version)
# evermore
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]
# folklore (deluxe version)
# folklore
# Lover
# reputation
# reputation Stadium Tour Surprise Song Playlist
# 1989 (Deluxe Edition)
# 1989
# Red (Deluxe Edition)
# Red
# Speak Now World Tour Live
# Speak Now (Deluxe Edition)
# Speak Now
# Fearless Platinum Edition
# Fearless
# Live From Clear Channel Stripped 2008
# Taylor Swift

# %% [markdown]
# Now it's your turn! Play around with the Spotify API!
#
# #### Short in-class activity
#
# 1. Get the name and release data of all the albums for your favorite artist on Spotify!
# 2. What is the oldest album of this artist?
#
# ***

# %%
zimmer_uri = '0YC192cP3KPCRWx8zr8MfZ'
results = spotify.artist_albums(zimmer_uri, album_type='album')
albums = results['items']
albums

while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
    print(album['release_date'])
# Out:
# The Tattooist of Auschwitz (Original Series Soundtrack)
# 2024-05-02
# The Weather Man (Music from the Motion Picture)
# 2024-05-01
# Kung Fu Panda 4 (Original Motion Picture Soundtrack)
# 2024-03-08
# Dune: Part Two (Original Motion Picture Soundtrack)
# 2024-02-23
# Planet Earth III (Original Television Soundtrack)
# 2023-12-08
# The Creator (Original Motion Picture Soundtrack)
# 2023-09-29
# Prehistoric Planet: Season 2 (Apple TV+ Original Series Soundtrack)
# 2023-05-22
# The Night Logan Woke Up (Original Series Soundtrack)
# 2023-03-17
# LIVE
# 2023-03-03
# The Zero Boys: Original Motion Picture Soundtrack
# 2022-12-23
# The Son (Original Motion Picture Soundtrack)
# 2022-11-18
# Frozen Planet II (Original Television Soundtrack)
# 2022-10-07
# Terminal Exposure: Original Motion Picture Soundtrack
# 2022-08-12
# Prehistoric Planet: Season 1 (Apple TV+ Original Series Soundtrack)
# 2022-06-24
# Top Gun: Maverick (Music From The Motion Picture)
# 2022-05-27
# The Survivor (Original Motion Picture Soundtrack)
# 2022-04-29
# The Wind: Original Motion Picture Soundtrack
# 2022-04-08
# Around The World In 80 Days (Music From The Original TV Series)
# 2022-01-30
# The Unforgivable (Soundtrack from the Netflix Film)
# 2021-12-10
# Army of Thieves (Soundtrack from the Netflix Film)
# 2021-11-12
# The Art and Soul of Dune (Companion Book Music)
# 2021-10-22
# No Time To Die (Original Motion Picture Soundtrack)
# 2021-10-01
# Dune (Original Motion Picture Soundtrack)
# 2021-09-17
# The Dune Sketchbook (Music from the Soundtrack)
# 2021-09-03
# The Boss Baby: Family Business (Original Motion Picture Soundtrack)
# 2021-07-02
# The SpongeBob Movie: Sponge on the Run (Music from the Motion Picture)
# 2021-04-16
# Wonder Woman 1984 (Sketches from the Soundtrack)
# 2021-02-05
# Wonder Woman 1984 (Original Motion Picture Soundtrack)
# 2020-12-16
# Hillbilly Elegy (Music from the Netflix Film)
# 2020-11-20
# Rebuilding Paradise (Original Motion Picture Soundtrack)
# 2020-11-06
# Gladiator: 20th Anniversary Edition
# 2020-05-09
# Xperiments from Dark Phoenix (Original Score)
# 2019-08-02
# Dark Phoenix (Original Motion Picture Soundtrack)
# 2019-06-07
# The World of Hans Zimmer - A Symphonic Celebration (Live)
# 2019-03-15
# Widows (Original Motion Picture Soundtrack)
# 2018-11-16
# The Journey: Champions (Original Soundtrack)
# 2018-09-28
# True Romance (Original Motion Picture Score)
# 2018-01-12
# The House of the Spirits (Original Motion Picture Soundtrack)
# 2017-12-15
# Live In Prague
# 2017-11-03
# Blue Planet II (Original Television Soundtrack)
# 2017-10-30
# Blade Runner 2049 (Original Motion Picture Soundtrack)
# 2017-10-05
# Dunkirk (Original Motion Picture Soundtrack)
# 2017-07-21
# The Boss Baby (Original Motion Picture Soundtrack)
# 2017-03-24
# Smilla's Sense of Snow (Original Motion Picture Soundtrack)
# 2017-02-24
# Hans Zimmer - The Classics
# 2017-01-13
# Hidden Figures - Original Score
# 2017-01-06
# Planet Earth II (Original Television Soundtrack)
# 2016-11-11
# Inferno (Original Motion Picture Soundtrack)
# 2016-10-14
# The Milan Years (Original Motion Picture Soundtrack)
# 2016-04-08
# Batman v Superman: Dawn Of Justice (Original Motion Picture Soundtrack) [Deluxe]
# 2016-03-18
# Kung Fu Panda 3 (Music from the Motion Picture)
# 2016-01-22
# Saints & Strangers (Music from the Miniseries)
# 2015-11-20
# Freeheld (Original Motion Picture Soundtrack)
# 2015-09-25
# The Little Prince (Original Motion Picture Soundtrack)
# 2015-08-06
# Epic Themes
# 2015-07-10
# Woman in Gold (Original Motion Picture Soundtrack)
# 2015-05-29
# Interstellar (Original Motion Picture Soundtrack) [Expanded Edition]
# 2014-11-18
# The Music of Hans Zimmer: The Definitive Collection
# 2014-07-28
# Winter's Tale (Original Motion Picture Soundtrack)
# 2014-02-04
# Man of Steel (Original Motion Picture Soundtrack) [Deluxe Edition]
# 2013-06-11
# Man of Steel (Original Motion Picture Soundtrack)
# 2013-06-11
# The Lone Ranger
# 2013-01-01
# The Bible (Official Score Soundtrack)
# 2013-01-01
# Music from the Batman Trilogy
# 2012-08-27
# The Dark Knight Rises (Original Motion Picture Soundtrack) [Deluxe Edition]
# 2012-07-17
# White Fang (Original Soundtrack)
# 2012-03-19
# Sherlock Holmes: A Game of Shadows (Original Motion Picture Soundtrack) [Deluxe Version]
# 2011-12-20
# Sherlock Holmes: A Game of Shadows (Original Motion Picture Soundtrack)
# 2011-12-13
# Skylanders: Spyro's Adventure (Original Game Soundtrack)
# 2011-10-24
# Crysis 2: Be Fast! (Original Videogame Soundtrack)
# 2011-04-26
# Kung Fu Panda 2 (Music From The Motion Picture)
# 2011-01-01
# Inception (Music from the Motion Picture)
# 2010-07-09
# Call of Duty: Modern Warfare 2 (Original Game Score)
# 2010-06-01
# The Pacific (Music From the HBO Miniseries)
# 2010-03-09
# Henri 4
# 2010-03-08
# Sherlock Holmes (Original Motion Picture Soundtrack)
# 2009-12-22
# Film Music of Hans Zimmer - Vol.1
# 2008-09-12
# The Dark Knight (Original Motion Picture Soundtrack)
# 2008-07-14
# The Dark Knight (Collectors Edition) [Original Motion Picture Soundtrack]
# 2008-07-14
# Kung Fu Panda - Original Motion Picture Soundtrack
# 2008-04-14
# Frost/Nixon (Original Motion Picture Soundtrack)
# 2008-01-01
# Music from the Pirates of the Caribbean Trilogy
# 2007-08-29
# The Simpsons Movie: The Music
# 2007-07-24
# The Holiday (Original Motion Picture Soundtrack)
# 2006-01-09
# The Da Vinci Code
# 2006-01-01
# Pearl Harbor - Original Motion Picture Soundtrack
# 2005-12-06
# Batman Begins (Original Motion Picture Soundtrack)
# 2005-06-14
# Hans Zimmer - The British Years
# 2005
# King Arthur
# 2004-01-01
# Matchstick Men (Original Motion Picture Soundtrack)
# 2003-01-01
# Spirit: Stallion Of The Cimarron (Music From The Original Motion Picture)
# 2002-05-04
# Spirit, l'étalon des plaines (Bande originale du film)
# 2002-05-04
# Black Hawk Down (Original Motion Picture Soundtrack)
# 2002-01-15
# More Music From The Motion Picture "Gladiator"
# 2001-02-07
# Gladiator - Music From The Motion Picture
# 2000-04-25
# An Everlasting Piece - Original Motion Picture Soundtrack
# 2000-01-01
# Mission: Impossible 2 (Music from the Original Motion Picture Score)
# 2000
# The Thin Red Line
# 1999-01-11
# The Big Picture
# 1997-05-01
# The Peacemaker
# 1997-01-01
# Something To Talk About (Original Motion Picture Score)
# 1995-01-01
# Crimson Tide
# 1995-01-01
# Nine Months (Original Motion Picture Soundtrack)
# 1995
# Renaissance Man (Original Motion Picture Soundtrack)
# 1994-01-01
# Radio Flyer (Original Score)
# 1992-03-27
# Millennium (Reissue)
# 1992-01-01
# Green Card (Original Motion Picture Soundtrack)
# 1991-01-01
# Pacific Heights (Original Motion Picture Soundtrack)
# 1990-01-01
# Les inédits
# 1989-10-30

# %% [markdown]
# ##### Part 2: Google Maps API
#
# 1. This uses the Google Developer Console.
#     - Navigate to: https://console.developers.google.com/apis/credentials?project=_
#     - Log in to your Google account
#     - Create a new project
#     - Creat your credentials using the API key option
#     - Get your API Key
#     - Modify the api key in `start_google.py`
#     - Save file changes
#     - Go to library (in your developer console API and Services) and enable `Geocoding API` and `Distance Matrix API`

# %% [markdown]
# 2. Installation

# %%
 # !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.7.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (pyproject.toml): started
#   Building wheel for googlemaps (pyproject.toml): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40745 sha256=dc751f0ced0d5c6264da29638c55d99bdc4dcf08efac76d6e098c0a47901c996
#   Stored in directory: c:\users\aleas\appdata\local\pip\cache\wheels\4c\6a\a7\bbc6f5c200032025ee655deb5e163ce8594fa05e67d973aad6
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %% [markdown]
# 3. Import your credentials from start_google.py

# %%
import importlib
imported_items = importlib.import_module('start_google')

# %% [markdown]
# Let's play around with it

# %%
# Copy client to an object named gmaps
gmaps = imported_items.client
# gmaps

# %%
# Locate the white house
#this search works for well known land marks, for blueberry hill 'Blueberry Hill St. Louis' works
whitehouse = 'The White House'
location = gmaps.geocode(whitehouse)
location # location is a list of dictionaries
# Out:
# [{'address_components': [{'long_name': '1600',
#     'short_name': '1600',
#     'types': ['street_number']},
#    {'long_name': 'Pennsylvania Avenue Northwest',
#     'short_name': 'Pennsylvania Avenue NW',
#     'types': ['route']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}],
#   'formatted_address': '1600 Pennsylvania Avenue NW, Washington, DC 20500, USA',
#   'geometry': {'location': {'lat': 38.8976763, 'lng': -77.0365298},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 38.9003021302915,
#      'lng': -77.0352025197085},
#     'southwest': {'lat': 38.8976041697085, 'lng': -77.03790048029151}}},
#   'partial_match': True,
#   'place_id': 'ChIJ37HL3ry3t4kRv3YLbdhpWXE',
#   'plus_code': {'compound_code': 'VXX7+39 Washington, DC',
#    'global_code': '87C4VXX7+39'},
#   'types': ['establishment', 'point_of_interest', 'tourist_attraction']}]

# %%
# Get keys
location[0].keys()
# Out:
# dict_keys(['address_components', 'formatted_address', 'geometry', 'partial_match', 'place_id', 'plus_code', 'types'])

# %%
# Get geometry
location[0]['geometry'].keys()
# Out:
# dict_keys(['location', 'location_type', 'viewport'])

# %%
# Get location
location[0]['geometry']['location']
# Out:
# {'lat': 38.8976763, 'lng': -77.0365298}

# %%
# Store latlong
latlong = location[0]['geometry']['location']

# %%
# Get the destination using latlong
destination = gmaps.reverse_geocode(latlong)
destination
# Out:
# [{'address_components': [{'long_name': '1600',
#     'short_name': '1600',
#     'types': ['street_number']},
#    {'long_name': 'Pennsylvania Avenue Northwest',
#     'short_name': 'Pennsylvania Avenue NW',
#     'types': ['route']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}],
#   'formatted_address': '1600 Pennsylvania Avenue NW, Washington, DC 20500, USA',
#   'geometry': {'location': {'lat': 38.8976763, 'lng': -77.0365298},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 38.8990252802915,
#      'lng': -77.0351808197085},
#     'southwest': {'lat': 38.8963273197085, 'lng': -77.0378787802915}}},
#   'place_id': 'ChIJ37HL3ry3t4kRv3YLbdhpWXE',
#   'plus_code': {'compound_code': 'VXX7+39 Washington, DC, USA',
#    'global_code': '87C4VXX7+39'},
#   'types': ['establishment', 'point_of_interest', 'tourist_attraction']},
#  {'address_components': [{'long_name': '1600',
#     'short_name': '1600',
#     'types': ['street_number']},
#    {'long_name': 'Pennsylvania Avenue Northwest',
#     'short_name': 'Pennsylvania Avenue NW',
#     'types': ['route']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']},
#    {'long_name': '0005',
#     'short_name': '0005',
#     'types': ['postal_code_suffix']}],
#   'formatted_address': '1600 Pennsylvania Avenue NW, Washington, DC 20500, USA',
#   'geometry': {'location': {'lat': 38.89764, 'lng': -77.0363948},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 38.8989889802915,
#      'lng': -77.0350458197085},
#     'southwest': {'lat': 38.8962910197085, 'lng': -77.0377437802915}}},
#   'place_id': 'ChIJj29ffVS3t4kRssvmz4DOiZE',
#   'plus_code': {'compound_code': 'VXX7+3C Washington, DC, USA',
#    'global_code': '87C4VXX7+3C'},
#   'types': ['street_address']},
#  {'address_components': [{'long_name': 'VXX7+39',
#     'short_name': 'VXX7+39',
#     'types': ['plus_code']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'District of Columbia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'VXX7+39 Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.89774999999999,
#      'lng': -77.03649999999999},
#     'southwest': {'lat': 38.897625, 'lng': -77.036625}},
#    'location': {'lat': 38.8976763, 'lng': -77.0365298},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 38.89903648029149,
#      'lng': -77.03521351970849},
#     'southwest': {'lat': 38.89633851970849, 'lng': -77.0379114802915}}},
#   'place_id': 'GhIJeHKXDudyQ0ARFRUWgVZCU8A',
#   'plus_code': {'compound_code': 'VXX7+39 Washington, DC, USA',
#    'global_code': '87C4VXX7+39'},
#   'types': ['plus_code']},
#  {'address_components': [{'long_name': '20500',
#     'short_name': '20500',
#     'types': ['postal_code']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Washington, DC 20500, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.8980424,
#      'lng': -77.03527249999999},
#     'southwest': {'lat': 38.8970971, 'lng': -77.0378229}},
#    'location': {'lat': 38.8975003, 'lng': -77.0364766},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.8989187302915,
#      'lng': -77.03519871970848},
#     'southwest': {'lat': 38.8962207697085, 'lng': -77.0378966802915}}},
#   'place_id': 'ChIJM98wTKK3t4kRCRVem9SdMqs',
#   'types': ['postal_code']},
#  {'address_components': [{'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': '7',
#     'short_name': '7',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Northwest Washington, Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.9955566, 'lng': -77.0060597},
#     'southwest': {'lat': 38.8891955, 'lng': -77.1197502}},
#    'location': {'lat': 38.9380912, 'lng': -77.04493269999999},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.9955566, 'lng': -77.0060597},
#     'southwest': {'lat': 38.8891955, 'lng': -77.1197502}}},
#   'place_id': 'ChIJi7U4CaS3t4kR0m_KoPJ00Bw',
#   'types': ['neighborhood', 'political']},
#  {'address_components': [{'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'District of Columbia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.9958641, 'lng': -76.909393},
#     'southwest': {'lat': 38.7916449, 'lng': -77.119759}},
#    'location': {'lat': 38.9071923, 'lng': -77.0368707},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.9958641, 'lng': -76.909393},
#     'southwest': {'lat': 38.7916449, 'lng': -77.119759}}},
#   'place_id': 'ChIJW-T2Wt7Gt4kRKl2I1CJFUsI',
#   'types': ['locality', 'political']},
#  {'address_components': [{'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.995845, 'lng': -76.909393},
#     'southwest': {'lat': 38.791645, 'lng': -77.119759}},
#    'location': {'lat': 38.9059849, 'lng': -77.03341790000002},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.995845, 'lng': -76.909393},
#     'southwest': {'lat': 38.791645, 'lng': -77.119759}}},
#   'place_id': 'ChIJW-T2Wt7Gt4kRmKFUAsCO4tY',
#   'types': ['administrative_area_level_1', 'political']},
#  {'address_components': [{'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'United States',
#   'geometry': {'bounds': {'northeast': {'lat': 74.071038, 'lng': -66.885417},
#     'southwest': {'lat': 18.7763, 'lng': 166.9999999}},
#    'location': {'lat': 37.09024, 'lng': -95.712891},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 74.071038, 'lng': -66.885417},
#     'southwest': {'lat': 18.7763, 'lng': 166.9999999}}},
#   'place_id': 'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#   'types': ['country', 'political']}]

# %%
# sometimes you have to dig...
print(destination[0]["address_components"][1]['long_name'])
# Out:
# Pennsylvania Avenue Northwest

# %%
# Find Duke University
duke = gmaps.geocode('326 Perkins Library, Durham, NC 27708')
duke_loc = duke[0]['geometry']['location']
duke_loc
# Out:
# {'lat': 36.0021437, 'lng': -78.93851490000002}

# %%
# Find WUSTL
washu = gmaps.geocode('1 Brookings Dr, St. Louis, MO 63130')
washu_loc = washu[0]['geometry']['location']
washu_loc
# Out:
# {'lat': 38.6482446, 'lng': -90.30494159999999}

# %%
# Find the distance (in km) between Duke and WUSTL
distance = gmaps.distance_matrix(duke_loc, washu_loc)
print(distance['rows'][0]['elements'][0]['distance']['text'])
# Out:
# 1,302 km

# %%
# Plotting in Google Maps
# More information on https://github.com/vgm64/gmplot
# !pip install gmplot
# Out:
# Collecting gmplot
#   Downloading gmplot-1.4.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: requests in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from gmplot) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests->gmplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests->gmplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests->gmplot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aleas\appdata\local\programs\python\python312\lib\site-packages (from requests->gmplot) (2024.7.4)
# Downloading gmplot-1.4.1-py3-none-any.whl (164 kB)
# Installing collected packages: gmplot
# Successfully installed gmplot-1.4.1

# %%
from gmplot import gmplot
google_key = imported_items.api_key

# Get St. Louis
STL = gmaps.geocode('St. Louis')
STL[0]['geometry']['location']
latlongSTL = STL[0]['geometry']['location']

# %%
latlongSTL
# Out:
# {'lat': 38.6270025, 'lng': -90.19940419999999}

# %%
# Create plot area
plot1 = gmplot.GoogleMapPlotter(lat = latlongSTL['lat'], 
								lng = latlongSTL['lng'], 
								zoom = 13, 
								apikey = google_key)

# %%
# Create an object with places in STL
stl_places = ["Forest Park, St. Louis",
			"Missouri Botanical Garden, St. Louis",
			"Anheuser Busch, St. Louis",
			"Arch, St. Louis"]

# %%
# Create a function to find latlong for stl_places
def grab_latlng(place):
	x = gmaps.geocode(place)
	return (x[0]["geometry"]["location"]["lat"], x[0]["geometry"]["location"]["lng"])

# %%
# Run the function
l = [grab_latlng(i) for i in stl_places]
l
# Out:
# [(38.637152, -90.28579739999999),
#  (38.6127672, -90.25937979999999),
#  (38.6270025, -90.19940419999999),
#  (38.6251269, -90.1867504)]

# %%
# Use zip to assign lat and long to different objects
# zip(* ) means that the object l will be unpacked, 
# making each of its elements a separate argument
attraction_lats, attraction_lons = zip(*l)
# attraction_lats
attraction_lons
# Out:
# (-90.28579739999999, -90.25937979999999, -90.19940419999999, -90.1867504)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\aleas\\Downloads\\PythonCamp2024\\Day05\\Lecture'

# %%
# Add points to our plot
plot1.scatter(lats = attraction_lats, 
			  lngs = attraction_lons,
			  color = 'black',
			  size = 40,
			  marker = True)

# %%
# Draw the plot
plot1.draw(r'C:\\Users\\aleas\\Downloads\\PythonCamp2024\\Day05\\Lecture\\my_map.html')

# %% [markdown]
# Now it's your turn! Let's all create a map of St. Louis!
# ***

# %% [markdown]
# Tip: Here is a list of all public APIs:
# https://github.com/public-api-lists/public-api-lists
#
# Start thinking about what you want to do for your poster project!
#
# You could use any of the APIs that we cover in the course, or any APIs that you find interesting to get your data!
